# %% [markdown]
# <h1>Table of Contents<span class="tocSkip"></span></h1>
# <div class="toc"><ul class="toc-item"><li><span><a href="#Before-your-start:" data-toc-modified-id="Before-your-start:-1"><span class="toc-item-num">1&nbsp;&nbsp;</span>Before your start:</a></span><ul class="toc-item"><li><span><a href="#Uniform-Distribution" data-toc-modified-id="Uniform-Distribution-1.1"><span class="toc-item-num">1.1&nbsp;&nbsp;</span>Uniform Distribution</a></span></li><li><span><a href="#Normal-Distribution" data-toc-modified-id="Normal-Distribution-1.2"><span class="toc-item-num">1.2&nbsp;&nbsp;</span>Normal Distribution</a></span></li><li><span><a href="#Normal-Distribution-of-Real-Data" data-toc-modified-id="Normal-Distribution-of-Real-Data-1.3"><span class="toc-item-num">1.3&nbsp;&nbsp;</span>Normal Distribution of Real Data</a></span></li><li><span><a href="#Exponential-Distribution" data-toc-modified-id="Exponential-Distribution-1.4"><span class="toc-item-num">1.4&nbsp;&nbsp;</span>Exponential Distribution</a></span></li><li><span><a href="#Exponential-Distribution-of-Real-Data" data-toc-modified-id="Exponential-Distribution-of-Real-Data-1.5"><span class="toc-item-num">1.5&nbsp;&nbsp;</span>Exponential Distribution of Real Data</a></span></li></ul></li></ul></div>

# %% [markdown]
# # Before your start:
#
#     Read the README.md file
#     Comment as much as you can and use the resources (README.md file)
#     Happy learning!

# %% [markdown]
# In this exercise, we  will generate random numbers from the continuous disributions we learned in the lesson. There are two ways to generate random numbers:
#
# 1. Using the numpy library
# 1. using the Scipy library
#
# Use either or both of the lbraries in this exercise.

# %%
import numpy as np
import random
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns
from scipy.stats import expon

# %% [markdown]
# ## Uniform Distribution
#
# To generate uniform random numbers between any two given values using scipy, we can either use the following code or the code that we have
# discussed in class:

# %%
from scipy.stats import uniform
x = uniform.rvs(size=10)
a = 2
b = 3
randoms  = a + (b-a)*x
print(randoms)
# Out:
# [2.65353087 2.74693864 2.34244869 2.38910128 2.98140519 2.03991617
#  2.9278718  2.93918983 2.47727845 2.62793729]

# %% [markdown]
# **Your task:**
#
# 1. Based on the code above, write a function that generates uniformly distributed random numbers. There are several requirements for your function:
#     * It should accept 3 parameters:
#         * `bottom` - the lower boundary of the generated numbers
#         * `ceiling` - the upper boundary of the generated numbers
#         * `count` - how many numbers to generate
#     * It should return an array of uniformly distributed random numbers
#
# 1. Call your function with 2 sets of params below:
#     * bottom=10, ceiling=15, count=100
#     * bottom=10, ceiling=60, count=1,000
#
# 1. Plot the uniform distributions generated above using histograms, where x axis is the value and y axis is the count. Let the histogram's number of bins be 10.
#
# Your output should look like below:
#
# ![uniform distribution](ud.png)

# %%
# bottom=10, ceiling=15, count=100
x = uniform.rvs(size=100)
a = 10
b = 15
randoms_1  = a + (b-a)*x
print(randoms_1)
# Out:
# [10.47249903 12.7131283  14.49221571 13.93890787 11.58728219 10.30268554
#  14.19524809 11.8561439  11.8940268  10.67598885 12.08613473 11.79208988
#  13.03268671 11.00913105 13.43851008 13.66987207 11.24799971 10.67435198
#  10.84110353 12.48646855 10.73005645 10.53575577 12.33969291 12.55117271
#  12.23823196 13.46157571 14.54697481 12.00272576 10.58120822 10.39784835
#  10.17110657 13.58791746 10.30384934 10.86762171 11.4551213  12.47776921
#  10.2222602  12.75129805 13.69563944 12.19453084 11.97549082 12.83741964
#  13.57711501 12.39023129 12.18115548 14.54004507 12.45345882 10.15109237
#  12.81214405 14.75984243 10.47678846 12.12708869 12.36052915 13.76556365
#  14.85038525 14.65511941 13.79483307 10.47265608 12.54941643 10.84223546
#  13.31153732 13.80943392 12.21771436 13.8922785  13.29406613 12.75304724
#  13.32287415 13.11696095 11.4400824  11.86723508 12.30859616 12.25621873
#  14.3700287  12.17745725 14.37089251 11.51991247 10.52655928 10.07135841
# ...

# %%
# bottom=10, ceiling=60, count=1,000
x = uniform.rvs(size=1000)
a = 10
b = 60
randoms_2  = a + (b-a)*x
print(randoms_2)
# Out:
# [33.97755983 41.85429248 42.12028444 31.88111034 44.33232302 56.35892806
#  36.63196216 24.92105369 37.97184837 15.79466016 16.938157   41.23563386
#  17.10867547 27.89132403 39.34110801 56.49494745 23.54796115 15.30236397
#  30.51084668 34.28808827 41.5373419  46.16455432 21.75856817 58.07850748
#  12.15352853 49.68078641 45.01387946 57.13597443 39.74145619 31.23044103
#  10.38804468 44.41873949 50.541147   38.04197886 17.09337772 26.20295071
#  49.76256756 39.35363816 48.81417887 24.91440542 52.82221064 41.68468215
#  36.03089915 38.29374605 32.1914648  32.22962717 52.4647535  26.17324788
#  48.57772806 15.79867704 21.81478652 11.62675745 25.53884771 28.58560286
#  16.96082051 29.13094055 22.32622171 17.63577334 32.25851759 26.83435132
#  55.07048691 16.72996504 19.99907312 13.88791959 12.26838382 53.63474034
#  10.0772823  59.41932329 50.82636183 38.95025863 42.46301672 46.36758703
#  58.15191589 39.12587995 11.10702354 18.88584591 57.77161776 45.73958365
# ...

# %% [markdown]
# How are the two distributions different?

# %%
fig, axes = plt.subplots(nrows=1, ncols=2,figsize=(10,5), sharey = True)

axes[0].hist(randoms_1, histtype =  'stepfilled')
axes[1].hist(randoms_2, histtype =  'stepfilled')
axes[0].set_title('sample_size = 100')
axes[1].set_title('sample_size = 1000')
# Out:
# Text(0.5, 1.0, 'sample_size = 1000')

# %% [markdown]
# ## Normal Distribution
#
# 1. In the same way in the Uniform Distribution challenge, write a function that generates normally distributed random numbers.
# 1. Generate 1,000 normally distributed numbers with the average of 10 and standard deviation of 1
# 1. Generate 1,000 normally distributed numbers with the average of 10 and standard deviation of 50
# 2. Plot the distributions of the data generated.
#
# Expected output:
#
# ![normal distribution](nd.png)

# %%
x = uniform.rvs(size=1000)
a = 8
b = 12
randoms_3  = a + (b-a)*x
print(randoms_3)
# Out:
# [ 9.84961155  9.43898177  9.03571837 10.47108626 10.19730131  8.31710037
#   8.07120671 10.57360677 10.53590368  8.81254057 11.96411287  9.5395779
#  10.762354    9.70646101  9.90675457  9.14653901 11.65541309  8.55192346
#  11.70808091 10.17351143  9.91322154 11.14202483  9.40354962  9.98401323
#  11.61148301 10.32281932 11.79586379  8.454788    8.64367677  8.25370213
#  11.93858675  8.65174795  9.52351422  9.18483286  9.36488642  9.22342791
#  10.61380447 10.98259511  8.40300458 11.04995669  8.43743435 10.34143634
#   8.03201255 10.34950986 10.23549295  8.16774686  8.38457377  9.12170372
#  10.92510071 10.80646857  9.02755211 11.38230453 10.16399947  8.19136519
#  10.84395012 11.61248755 11.94317734 10.00929339  8.9199881   9.95954082
#   8.42961543 11.30029237 11.6800358   8.33825289  8.11623346 11.3478166
#   8.52141104 10.32852053  9.6896367  10.46399505 11.54769223 10.2775681
#  10.88379182 10.23447033 11.24459294 10.49950566 10.97167876 11.2857951
# ...

# %%
def create_normal(mean, std, size):
    randoms_3 = np.random.normal(mean, std, size)
    return randoms_3
randoms_3
# Out:
# array([ 9.84961155,  9.43898177,  9.03571837, 10.47108626, 10.19730131,
#         8.31710037,  8.07120671, 10.57360677, 10.53590368,  8.81254057,
#        11.96411287,  9.5395779 , 10.762354  ,  9.70646101,  9.90675457,
#         9.14653901, 11.65541309,  8.55192346, 11.70808091, 10.17351143,
#         9.91322154, 11.14202483,  9.40354962,  9.98401323, 11.61148301,
#        10.32281932, 11.79586379,  8.454788  ,  8.64367677,  8.25370213,
#        11.93858675,  8.65174795,  9.52351422,  9.18483286,  9.36488642,
#         9.22342791, 10.61380447, 10.98259511,  8.40300458, 11.04995669,
#         8.43743435, 10.34143634,  8.03201255, 10.34950986, 10.23549295,
#         8.16774686,  8.38457377,  9.12170372, 10.92510071, 10.80646857,
#         9.02755211, 11.38230453, 10.16399947,  8.19136519, 10.84395012,
#        11.61248755, 11.94317734, 10.00929339,  8.9199881 ,  9.95954082,
#         8.42961543, 11.30029237, 11.6800358 ,  8.33825289,  8.11623346,
# ...

# %%
randoms_4 = create_normal(10,1, 1000)
randoms_5 = create_normal(10,50, 1000)

# %% [markdown]
# How are the two distributions different?

# %%
fig, axes = plt.subplots(nrows=1, ncols=2,figsize=(10,5), sharey = True)

# %%
fig, axes = plt.subplots(nrows=1, ncols=2,figsize=(10,5), sharey = True)
axes[0].hist(randoms_4, histtype =  'stepfilled', color = 'pink', bins = 50)
axes[1].hist(randoms_5, histtype =  'stepfilled', color = 'pink', bins = 50)
# Out:
# (array([ 1.,  1.,  0.,  2.,  3.,  3.,  0.,  6.,  5.,  7., 16., 16., 15.,
#         15., 21., 34., 37., 48., 53., 57., 55., 48., 55., 57., 47., 74.,
#         44., 40., 47., 36., 28., 30., 22., 18., 11., 10.,  8., 10.,  9.,
#          3.,  0.,  3.,  1.,  1.,  0.,  1.,  0.,  1.,  0.,  1.]),
#  array([-150.53233247, -143.46189991, -136.39146735, -129.32103479,
#         -122.25060223, -115.18016968, -108.10973712, -101.03930456,
#          -93.968872  ,  -86.89843944,  -79.82800688,  -72.75757432,
#          -65.68714177,  -58.61670921,  -51.54627665,  -44.47584409,
#          -37.40541153,  -30.33497897,  -23.26454642,  -16.19411386,
#           -9.1236813 ,   -2.05324874,    5.01718382,   12.08761638,
#           19.15804894,   26.22848149,   33.29891405,   40.36934661,
#           47.43977917,   54.51021173,   61.58064429,   68.65107684,
#           75.7215094 ,   82.79194196,   89.86237452,   96.93280708,
#          104.00323964,  111.0736722 ,  118.14410475,  125.21453731,
# ...

# %% [markdown]
# ## Normal Distribution of Real Data
#
# In this challenge we are going to take a look the real data. We will use vehicles.csv file for this exercise

# %% [markdown]
# First import vehicles.csv.
# Then plot the histograms for the following variables:
#
# 1. Fuel Barrels/Year

# %%
cars = pd.read_csv("vehicles.csv")

# %%
sns.histplot(cars, element='bars');

# %%
plt.hist(cars['Fuel Barrels/Year']);

# %% [markdown]
# 2. CO2 Emission Grams/Mile

# %%
plt.hist(cars['CO2 Emission Grams/Mile']);

# %% [markdown]
# 3. Combined MPG

# %%
plt.hist(cars['Combined MPG']);

# %% [markdown]
# Which one(s) of the variables are nearly normally distributed? How do you know?

# %%
# todas parecen una campana de gaus mas o menos, 
# creo que las tres tienen una distribucion normal.

# %% [markdown]
# ## Exponential Distribution

# %% [markdown]
# 1. Using `numpy.random.exponential`, create a function that returns a list of numbers exponentially distributed with the mean of 10.
#
# 1. Use the function to generate two number sequences with the size of 10 and 100.
#
# 1. Plot the distributions as histograms with the nubmer of bins as 100.
#
# Your output should look like below:
#
# ![exponential distribution](ed.png)

# %%
def create_exponential(mean, size):
    return  np.random.exponential(mean, size)

# %%
seq1 = create_exponential(10, 10)
seq2 = create_exponential(10,100)

# %%
plt.hist(seq1, bins = 100);

# %%
plt.hist(seq2, bins = 100);

# %% [markdown]
# How are the two distributions different?

# %%
# yo creo que he hecho algo mal 
# porque la primera no tiene forma y el eje y es diferente

# %% [markdown]
# ## Exponential Distribution of Real Data
#
# Suppose that the amount of time one spends in a bank is exponentially distributed with mean as 10 minutes (i.e. λ = 1/10). What is the probability that a customer will spend less than fifteen minutes in the bank?
#
# Write a code in python to solve this problem

# %%
import math

# %%
# your answer here
# Hint: This is same as saying P(x<15)

# %%
lam=1/10

# %%
Prob15 = 1 - math.exp(-lam * 15)
Prob15
# Out:
# 0.7768698398515702

# %% [markdown]
# What is the probability that the customer will spend more than 15 minutes

# %%
Prob15plus = math.exp(-lam * 15)
Prob15plus
# Out:
# 0.22313016014842982
