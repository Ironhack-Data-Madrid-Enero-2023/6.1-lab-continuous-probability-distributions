# %% [markdown]
# <h1>Table of Contents<span class="tocSkip"></span></h1>
# <div class="toc"><ul class="toc-item"><li><span><a href="#Before-your-start:" data-toc-modified-id="Before-your-start:-1"><span class="toc-item-num">1&nbsp;&nbsp;</span>Before your start:</a></span><ul class="toc-item"><li><span><a href="#Uniform-Distribution" data-toc-modified-id="Uniform-Distribution-1.1"><span class="toc-item-num">1.1&nbsp;&nbsp;</span>Uniform Distribution</a></span></li><li><span><a href="#Normal-Distribution" data-toc-modified-id="Normal-Distribution-1.2"><span class="toc-item-num">1.2&nbsp;&nbsp;</span>Normal Distribution</a></span></li><li><span><a href="#Normal-Distribution-of-Real-Data" data-toc-modified-id="Normal-Distribution-of-Real-Data-1.3"><span class="toc-item-num">1.3&nbsp;&nbsp;</span>Normal Distribution of Real Data</a></span></li><li><span><a href="#Exponential-Distribution" data-toc-modified-id="Exponential-Distribution-1.4"><span class="toc-item-num">1.4&nbsp;&nbsp;</span>Exponential Distribution</a></span></li><li><span><a href="#Exponential-Distribution-of-Real-Data" data-toc-modified-id="Exponential-Distribution-of-Real-Data-1.5"><span class="toc-item-num">1.5&nbsp;&nbsp;</span>Exponential Distribution of Real Data</a></span></li></ul></li></ul></div>

# %% [markdown]
# # Before your start:
#
#     Read the README.md file
#     Comment as much as you can and use the resources (README.md file)
#     Happy learning!

# %% [markdown]
# In this exercise, we  will generate random numbers from the continuous disributions we learned in the lesson. There are two ways to generate random numbers:
#
# 1. Using the numpy library
# 1. using the Scipy library
#
# Use either or both of the lbraries in this exercise.

# %% [markdown]
# ## Uniform Distribution
#
# To generate uniform random numbers between any two given values using scipy, we can either use the following code or the code that we have
# discussed in class:

# %%
from scipy.stats import uniform
x = uniform.rvs(size=10)
a = 2
b = 3
randoms  = a + (b-a)*x
print(randoms)
# Out:
# [2.32907425 2.22257473 2.89762492 2.72075723 2.67882306 2.56111252
#  2.33995043 2.08865342 2.52839314 2.56878018]

# %% [markdown]
# **Your task:**
#
# 1. Based on the code above, write a function that generates uniformly distributed random numbers. There are several requirements for your function:
#     * It should accept 3 parameters:
#         * `bottom` - the lower boundary of the generated numbers
#         * `ceiling` - the upper boundary of the generated numbers
#         * `count` - how many numbers to generate
#     * It should return an array of uniformly distributed random numbers
#
# 1. Call your function with 2 sets of params below:
#     * bottom=10, ceiling=15, count=100
#     * bottom=10, ceiling=60, count=1,000
#
# 1. Plot the uniform distributions generated above using histograms, where x axis is the value and y axis is the count. Let the histogram's number of bins be 10.
#
# Your output should look like below:
#
# ![uniform distribution](ud.png)

# %%
def uniform_dist(bottom, ceiling, count):
    
    x = uniform.rvs(size=count)
    
    a = ceiling
    
    b = bottom
    
    return a + (b-a)*x

# %%
muestra1= uniform_dist(10, 15, 100)

muestra1
# Out:
# array([14.86604606, 10.2443251 , 13.85393421, 12.47889414, 12.2211641 ,
#        12.28867482, 10.85572278, 11.8477473 , 11.3250121 , 14.504501  ,
#        13.94675296, 13.32307716, 11.46228169, 10.07452863, 13.80258364,
#        11.65873355, 12.85791279, 14.9732073 , 10.29709635, 10.19833405,
#        14.96155636, 11.14171001, 10.23611823, 12.88304122, 14.38052992,
#        12.44928465, 11.39613296, 11.61873936, 12.76504215, 11.7863459 ,
#        14.93546732, 12.68810442, 11.05822735, 12.2291643 , 11.42668794,
#        14.79834429, 14.04514919, 10.20406871, 14.67493288, 11.09915974,
#        14.82830337, 13.59516133, 12.98878334, 11.64270853, 13.21402686,
#        14.27103957, 14.91524132, 10.16241076, 14.64264111, 12.79188375,
#        12.45010453, 12.13404148, 12.29251419, 13.51167214, 14.89995987,
#        12.08223751, 13.57033148, 10.86034112, 12.78627306, 12.87723356,
#        11.0836272 , 10.78553516, 11.73611025, 11.67129154, 14.65226652,
# ...

# %%
import pylab as plt
import seaborn as sns
sns.histplot(muestra1, element='step');

# %%
muestra2= uniform_dist(15, 60, 1000)
muestra2
# Out:
# array([42.6894397 , 37.04055145, 49.06202669, 26.59059043, 52.96850001,
#        19.05335932, 36.73093676, 41.32619368, 34.08732958, 16.76727758,
#        39.05341779, 17.4649346 , 16.94855163, 39.7603133 , 54.61492537,
#        52.56187365, 27.70570462, 59.85296457, 38.94637301, 29.81997759,
#        16.54637802, 43.49227261, 45.64113018, 25.51537331, 54.04897705,
#        39.18210233, 38.2321332 , 35.09608674, 24.58951847, 32.35110847,
#        29.03896846, 55.15949535, 56.42080318, 17.95519864, 19.45753968,
#        31.11671739, 24.5424669 , 32.15819174, 34.99289306, 50.44859903,
#        51.95528629, 29.33814144, 46.30792011, 50.47114002, 56.26693578,
#        58.6032822 , 27.39539779, 36.97858239, 31.48112638, 52.95533682,
#        48.61922536, 48.82925625, 44.15146993, 17.02820106, 22.29141596,
#        48.06720183, 36.13822209, 26.57790383, 17.83030015, 54.78306295,
#        47.667072  , 30.22335296, 20.30520026, 47.70559618, 24.77377161,
# ...

# %%
sns.histplot(muestra2, element='step');

# %% [markdown]
# How are the two distributions different?

# %%
#son diferentes en el tamaño de la muestra y en los intervalos.

# %% [markdown]
# ## Normal Distribution
#
# 1. In the same way in the Uniform Distribution challenge, write a function that generates normally distributed random numbers.
# 1. Generate 1,000 normally distributed numbers with the average of 10 and standard deviation of 1
# 1. Generate 1,000 normally distributed numbers with the average of 10 and standard deviation of 50
# 2. Plot the distributions of the data generated.
#
# Expected output:
#
# ![normal distribution](nd.png)

# %%
from scipy.stats import norm

def ndist(count,average,stdevi):
    
    troncho = norm(loc=average, scale=stdevi)
    muestrarandom = troncho.rvs(size=count)
    
    
    return muestrarandom

# %%
m1= ndist(1000,10,1)
m1
# Out:
# array([11.01772599,  8.79661912,  9.88097258,  8.74068639, 10.33043877,
#         9.02453514, 10.3515863 ,  9.98848655, 10.55962047, 11.03843583,
#         9.88590004,  9.56210735, 10.45883184,  8.75735782, 10.28813714,
#         9.53596029,  9.45658752,  9.93190545,  9.6465973 ,  9.79343461,
#        10.07231951,  7.57289577, 10.66014812,  9.61583613,  9.04652394,
#        11.98070597,  9.56931213, 10.82939691,  8.39341083, 10.02751669,
#         9.06935877, 11.43294313, 12.14327111,  9.1007159 , 10.15933349,
#        10.49303725, 11.08006375,  8.77013596, 11.86907395,  9.7637517 ,
#        11.21964613, 10.08157095, 10.36463606,  9.29121133, 10.17967505,
#        10.13763906, 11.25013631, 10.05772121,  9.16146226,  8.58831745,
#         9.38792623,  8.1131399 ,  9.51326502,  7.82238922,  9.96514402,
#        10.02258293, 10.09964344, 10.99472766,  8.51586271,  9.67157436,
#        10.46414105, 12.18421566,  9.63001359, 11.9858127 , 10.07209734,
# ...

# %%
m2= ndist(1000,10,50)
m2
# Out:
# array([-7.65955386e+01, -9.39682598e+00, -6.52666781e+01,  7.86105788e+01,
#         2.06740030e+01,  1.25302006e+01,  5.47310419e+01, -4.82192384e-01,
#         1.11380360e+02, -4.30819426e+00, -2.24532764e+01,  7.01433382e+00,
#         4.03523941e+01,  3.38675287e+00,  8.70988994e+01,  4.09935721e+01,
#        -1.10863361e+01,  6.59748186e+01, -3.14208980e+01, -5.87651384e-01,
#         1.11134668e+01, -7.72908822e+01, -7.15519532e+01,  4.03112225e+01,
#         1.87141216e+01, -1.79141181e+01,  1.57805632e+01,  1.30486643e+01,
#         8.21825155e+00,  7.74025077e+01, -6.21599320e+01,  3.20593864e+01,
#        -5.19955668e+00,  2.51900360e+01,  1.05807252e+02,  3.90719658e+00,
#         6.24845652e+01, -3.55535045e+01, -2.99087662e+01,  3.18927652e+01,
#        -1.46895521e+00,  1.64050645e+01,  2.38266857e+01, -8.11315058e+01,
#        -6.31730055e+00, -7.19591475e+01,  6.80761401e+01,  2.76158340e+00,
# ...

# %%
sns.histplot(m1, element='step');

# %%
sns.histplot(m2, element='step');

# %% [markdown]
# How are the two distributions different?

# %%
#la media del primero está en 10 y la del segundo en 0. El rango es distinto.

# %% [markdown]
# ## Normal Distribution of Real Data
#
# In this challenge we are going to take a look the real data. We will use vehicles.csv file for this exercise

# %% [markdown]
# First import vehicles.csv.
# Then plot the histograms for the following variables:
#
# 1. Fuel Barrels/Year

# %%
import pandas as pd


cars_ori = pd.read_csv('vehicles.csv', encoding = 'latin1')

cars = cars_ori.copy()

# %%
cars.head(1)
# Out:
#          Make              Model  Year  Engine Displacement  Cylinders  \
# 0  AM General  DJ Po Vehicle 2WD  1984                  2.5        4.0
#
#       Transmission     Drivetrain                Vehicle Class Fuel Type  \
# 0  Automatic 3-spd  2-Wheel Drive  Special Purpose Vehicle 2WD   Regular
#
#    Fuel Barrels/Year  City MPG  Highway MPG  Combined MPG  \
# 0          19.388824        18           17            17
#
#    CO2 Emission Grams/Mile  Fuel Cost/Year
# 0               522.764706            1950

# %%
sns.histplot(cars['Fuel Barrels/Year'], element='step');

# %% [markdown]
# 2. CO2 Emission Grams/Mile

# %%
sns.histplot(cars['CO2 Emission Grams/Mile'], element='step');

# %% [markdown]
# 3. Combined MPG

# %%
sns.histplot(cars['Combined MPG'], element='step');

# %% [markdown]
# Which one(s) of the variables are nearly normally distributed? How do you know?

# %%
#El tercer gráfico, ya que los valores crecen y decrecen más uniformemente hacia ambos lados.

# %% [markdown]
# ## Exponential Distribution

# %% [markdown]
# 1. Using `numpy.random.exponential`, create a function that returns a list of numbers exponentially distributed with the mean of 10.
#
# 1. Use the function to generate two number sequences with the size of 10 and 100.
#
# 1. Plot the distributions as histograms with the nubmer of bins as 100.
#
# Your output should look like below:
#
# ![exponential distribution](ed.png)

# %%
import numpy as np

def generate_exponential(mean, size):
    return np.random.exponential(scale=mean, size=size)

# %%
sns.histplot(generate_exponential(10, 10), element='step', bins = 100);

# %%
sns.histplot(generate_exponential(10, 100), element='step', bins = 100);

# %% [markdown]
# How are the two distributions different?

# %%
#la primera curva tiene un numero tan reducido de elementos que no se puede apreciar el decrecimiento exponencial.

# %% [markdown]
# ## Exponential Distribution of Real Data
#
# Suppose that the amount of time one spends in a bank is exponentially distributed with mean as 10 minutes (i.e. λ = 1/10). What is the probability that a customer will spend less than fifteen minutes in the bank?
#
# Write a code in python to solve this problem

# %%
# your answer here
# Hint: This is same as saying P(x<15

import math 
mean = 10
lmbda = 1/mean
x = 15

prob = 1 - lmbda*math.e**(-lmbda*x)


prob
# Out:
# 0.977686983985157

# %% [markdown]
# What is the probability that the customer will spend more than 15 minutes

# %%
mean = 10
lmbda = 1/mean
x = 15

prob2 = lmbda*math.e**(-lmbda*x)


prob2
# Out:
# 0.022313016014842986
